# %% [markdown]
# <div style='background-color: orange'>
# <a id='TableOfContents'></a>
#     <b><u><i><h1 style='text-align: center'>
#         Table of Contents
#     </h1></i></u></b>
# <li><a href='#imports'>Imports</a></li>
# <li><a href='#acquire'>Acquire</a></li>
# <li><a href='#py'>'.py' File Test</a></li>
# <li><a href='#misc'>Miscellaneous</a></li>

# %% [markdown]
# <div style='background-color: orange'>
# <a id='imports'></a>
#     <b><u><i><h1 style='text-align: center'>
#         Imports
#     </h1></i></u></b>
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Vectorization and dataframing
import numpy as np
import pandas as pd

# .py files
import acquire

# %% [markdown]
# <div style='background-color: orange'>
# <a id='acquire'></a>
#     <b><u><i><h1 style='text-align: center'>
#         Acquire
#     </h1></i></u></b>
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
mass_shooters = pd.read_excel('mass_shooters.xlsx', sheet_name='Full Database', header=1)
mass_shooters.head()
# Out:
#   Case # Shooter Last Name Shooter First Name   Full Date Day of Week Day  \
# 0      1           Whitman            Charles    8/1/1966      Monday   1
# 1      2             Smith             Robert  11/12/1966    Saturday  12
# 2      3              Held                Leo  10/23/1967      Monday  23
# 3      4           Pearson               Eric   3/16/1968    Saturday  16
# 4      5         Lambright             Donald    4/5/1969    Saturday   5
#
#    Month  Year               Street Number      Street Name  ...  \
# 0      8  1966                         110  Inner Campus Dr  ...
# 1     11  1966  Rose-Mar College of Beauty           N Rose  ...
# 2     10  1967                         599    S Highland St  ...
# 3      3  1968                       11703          Lake Rd  ...
# 4      4  1969                         NaN             I-76  ...
#
#   Interest in Firearms Firearm Proficiency  \
# 0                  1.0                 3.0
# 1                  0.0                 1.0
# 2                  1.0                 3.0
# 3                  0.0                 0.0
# 4                  0.0                 3.0
#
#   Total Firearms Brought to the Scene  Other Weapons or Gear  \
# 0                                 7.0                    1.0
# 1                                 1.0                    1.0
# 2                                 2.0                    1.0
# 3                                 1.0                    0.0
# 4                                 2.0                    0.0
#
#                        Specify Other Weapons or Gear  On-Scene Outcome  \
# 0  hatchet, hammer, knives, wrench, ropes, water,...               1.0
# 1                                  knife, nylon cord               2.0
# 2                                            holster               1.0
# 3                                                NaN               2.0
# 4                                                NaN               0.0
#
#    Who Killed Shooter On Scene  Attempt to Flee  Insanity Defense  \
# 0                          2.0              0.0               2.0
# 1                          0.0              0.0               1.0
# 2                          2.0              0.0               2.0
# 3                          0.0              0.0               0.0
# 4                          1.0              0.0               2.0
#
#   Criminal Sentence
# 0               0.0
# 1               1.0
# 2               0.0
# 3               3.0
# 4               0.0
#
# [5 rows x 153 columns]

# %% [markdown]
# <div style='background-color: orange'>
# <a id='py'></a>
#     <b><u><i><h1 style='text-align: center'>
#         '.py' File Test
#     </h1></i></u></b>
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
mass_shooters_py = acquire.acquire_mass_shooters()
mass_shooters_py.head()
# Out:
#   Case # Shooter Last Name Shooter First Name   Full Date Day of Week Day  \
# 0      1           Whitman            Charles    8/1/1966      Monday   1
# 1      2             Smith             Robert  11/12/1966    Saturday  12
# 2      3              Held                Leo  10/23/1967      Monday  23
# 3      4           Pearson               Eric   3/16/1968    Saturday  16
# 4      5         Lambright             Donald    4/5/1969    Saturday   5
#
#    Month  Year               Street Number      Street Name  ...  \
# 0      8  1966                         110  Inner Campus Dr  ...
# 1     11  1966  Rose-Mar College of Beauty           N Rose  ...
# 2     10  1967                         599    S Highland St  ...
# 3      3  1968                       11703          Lake Rd  ...
# 4      4  1969                         NaN             I-76  ...
#
#   Interest in Firearms Firearm Proficiency  \
# 0                  1.0                 3.0
# 1                  0.0                 1.0
# 2                  1.0                 3.0
# 3                  0.0                 0.0
# 4                  0.0                 3.0
#
#   Total Firearms Brought to the Scene  Other Weapons or Gear  \
# 0                                 7.0                    1.0
# 1                                 1.0                    1.0
# 2                                 2.0                    1.0
# 3                                 1.0                    0.0
# 4                                 2.0                    0.0
#
#                        Specify Other Weapons or Gear  On-Scene Outcome  \
# 0  hatchet, hammer, knives, wrench, ropes, water,...               1.0
# 1                                  knife, nylon cord               2.0
# 2                                            holster               1.0
# 3                                                NaN               2.0
# 4                                                NaN               0.0
#
#    Who Killed Shooter On Scene  Attempt to Flee  Insanity Defense  \
# 0                          2.0              0.0               2.0
# 1                          0.0              0.0               1.0
# 2                          2.0              0.0               2.0
# 3                          0.0              0.0               0.0
# 4                          1.0              0.0               2.0
#
#   Criminal Sentence
# 0               0.0
# 1               1.0
# 2               0.0
# 3               3.0
# 4               0.0
#
# [5 rows x 153 columns]

# %% [markdown]
# <div style='background-color: orange'>
# <a id='misc'></a>
#     <b><u><i><h1 style='text-align: center'>
#         Miscellaneous
#     </h1></i></u></b>
# <li><a href='#TableOfContents'>Table of Contents</a></li>
